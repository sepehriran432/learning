# %%
number = 1

# %%
another_number = 3.4

# %%
type(number)
# Out:
# int

# %%
type(another_number)
# Out:
# float

# %%
summon = another_number + number

# %%
print(summon)
# Out:
# 4.4

# %%
type(summon)
# Out:
# float

# %%
b = int(summon)

# %%
print(b)
# Out:
# 4
