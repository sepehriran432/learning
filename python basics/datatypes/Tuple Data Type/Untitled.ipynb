# %%
family_tuple = ("sepehr", "soheal", "naimeh", "ali")

# %%
family_tuple[0]
# Out:
# 'sepehr'

# %%
family_tuple[0] = "yeki"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 family_tuple[0] = "yeki"
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(family_tuple)
# Out:
# tuple

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
tup = (5 ,)

# %%
type(tup)
# Out:
# tuple

# %%
tup = (5)

# %%
type(tup)
# Out:
# int

# %%
tup = (1,2,[1,4])

# %%
tup[2][0] -= 1

# %%
tup
# Out:
# (1, 2, [0, 4])
