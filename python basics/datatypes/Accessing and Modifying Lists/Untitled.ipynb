# %%
names = ["sepehr", "soheal"]

# %%
names[-1]
# Out:
# 'soheal'

# %%
names[-2]
# Out:
# 'sepehr'

# %%
names.append(["naimeh", "ali"])

# %%
names
# Out:
# ['sepehr', 'soheal', ['naimeh', 'ali']]

# %%
names.extend([["amirfoad", "sajjad", "hamidreza (lyam)", "ali", "naimeh", "fatemeh", "tahereh"]])

# %%
names
# Out:
# ['sepehr',
#  'soheal',
#  ['naimeh', 'ali'],
#  ['amirfoad',
#   'sajjad',
#   'hamidreza (lyam)',
#   'ali',
#   'naimeh',
#   'fatemeh',
#   'tahereh']]

# %%
mom = names[2][0]

# %%
dad = names[2][1]

# %%
uncles = names[3][0:3]

# %%
brothers = names[0:2]

# %%
brothers
# Out:
# ['sepehr', 'soheal']
