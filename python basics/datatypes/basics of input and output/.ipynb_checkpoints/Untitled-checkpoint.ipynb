# %%
name = input("enter your name:‌ ")
# Out:
# enter your name:‌  sepehr

# %%
name
# Out:
# 'sepehr'

# %%
age = int(input("enter your age: "))
# Out:
# enter your age:  15

# %%
age
# Out:
# 15

# %%
type(age)
# Out:
# int

# %%
18 - age
# Out:
# 3

# %%
print("I,m", age, "years old")
# Out:
# I,m 15 years old

# %%
the_end = str(18 - age) + " years left"

# %%
the_end
# Out:
# '3 years left'
