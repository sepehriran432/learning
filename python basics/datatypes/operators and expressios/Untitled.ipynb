# %%
41414411 - 9999999999
# Out:
# -9958585588

# %%
50 + 50
# Out:
# 100

# %%
6 / 2
# Out:
# 3.0

# %%
12 * 99
# Out:
# 1188

# %%
12 // 2
# Out:
# 6

# %%
12 % 3
# Out:
# 0

# %%
14 % 3
# Out:
# 2

# %%
9 ** 2
# Out:
# 81

# %%
4 - 2
# Out:
# 2

# %%
a = 2

# %%
b = 3

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a < b
# Out:
# True

# %%
b <= a
# Out:
# False

# %%
a = b

# %%
a <= b
# Out:
# True

# %%
current_level = 10

# %%
target_level = 20

# %%
playtime = 30

# %%
current_level = 10
target_level = 20
playtime = 9
limitations = (current_level <= target_level) and (playtime >= 10)
print(limitations)
playtime += 3
current_level += 10000
print(limitations)
# Out:
# False
# False

# %%
current_level += 25

# %%
print(limitations)
# Out:
# True

# %%
current_level += 1000000000

# %%
print(limitations)
# Out:
# True

# %%
"u" in "github"
# Out:
# True

# %%
'u' not in 'github'
# Out:
# False

# %%
5 and 3
# Out:
# 3

# %%
5 & 3
# Out:
# 1

# %%
#yeah, i am iron wind
