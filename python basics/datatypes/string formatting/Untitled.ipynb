# %%
age = "you,re {} years old"

# %%
age_r = input("enter your age")
# Out:
# enter your age 15

# %%
age.format(age_r)
# Out:
# 'you,re 15 years old'

# %%
message = "your name is {name} and your age is {age_r} and you love {thing}"

# %%
name = input("enter your name")
# Out:
# enter your name sepehr

# %%
message.format(name=name, age_r=age_r, thing="computers")
# Out:
# 'your name is sepehr and your age is 15 and you love computers'

# %%
print(f"I am {name} and I,m {age_r}")
# Out:
# I am sepehr and I,m 15
