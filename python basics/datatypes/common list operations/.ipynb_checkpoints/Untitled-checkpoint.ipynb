# %%
list1 = [1,2,3,1]
list2 = [4,5,6]

# %%
list1 +list2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
(list1 + list2) * 2
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
3 in list2
# Out:
# False

# %%
3 in list1
# Out:
# True

# %%
3 not in list2
# Out:
# True

# %%
list2.index(4)
# Out:
# 0

# %%
list2.index(5)
# Out:
# 1

# %%
list1.count(1)
# Out:
# 2

# %%
list1
# Out:
# [1, 2, 3, 1]

# %%
list1.reverse()

# %%
list1
# Out:
# [1, 3, 2, 1]

# %%
list(reversed(list1))
# Out:
# [1, 2, 3, 1]

# %%
list1
# Out:
# [1, 3, 2, 1]

# %%
list1.sort()

# %%
list1
# Out:
# [1, 1, 2, 3]

# %%
sorted(list1)
# Out:
# [1, 1, 2, 3]
