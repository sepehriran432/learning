# %%
[]
# Out:
# []

# %%
numbers = [0, 1, 2, 3, 4, 5]

# %%
numbers[0]
# Out:
# 0

# %%
numbers[1]
# Out:
# 1

# %%
scores = [2, "sepehr", 0, "soheal"]

# %%
scores[0] += 999*999

# %%
scores
# Out:
# [998003, 'sepehr', 0, 'soheal']

# %%
scores_end = tuple(scores)

# %%
type(scores_end)
# Out:
# tuple

# %%
scores_end[0] += 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 scores_end[0] += 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
[scores_end[0], scores_end[1]] * 4
# Out:
# [998003, 'sepehr', 998003, 'sepehr', 998003, 'sepehr', 998003, 'sepehr']

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
len(list(range(100)))
# Out:
# 100

# %%
max(list(range(100)))
# Out:
# 99

# %%
min(list(range(100)))
# Out:
# 0

# %%
sum(list(range(1000)))
# Out:
# 499500
