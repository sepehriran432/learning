# %%
[1, "sepehr", 0, "soheal"]
# Out:
# [1, 'sepehr', 0, 'soheal']

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
[1, [10,11],]
# Out:
# [1, [10, 11]]

# %%
mylist = [1, "sepehr", 0, "soheal"]

# %%
sepehr_score = mylist[0]

# %%
sepehr_score
# Out:
# 1

# %%
sepehr_score += 1

# %%
sepehr_score
# Out:
# 2

# %%
(1, "not", 2, "mutable")
# Out:
# (1, 'not', 2, 'mutable')

# %%
mytuple = (1, "not", 2, "mutable")

# %%
mytuple[0]
# Out:
# 1

# %%
mytuple[0] += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mytuple[0] += 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
{2,0,2,0}
# Out:
# {0, 2}

# %%
status = {
    "sepehr": 2,
    "soheal": 0
}

# %%
status
# Out:
# {'sepehr': 2, 'soheal': 0}

# %%
status["sepehr"]
# Out:
# 2
