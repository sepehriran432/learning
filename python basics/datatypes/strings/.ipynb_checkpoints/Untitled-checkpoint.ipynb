# %%
my_name = "sepehr"

# %%
my_book = "sepehr's book"

# %%
my_info = """ 
15 years old researcher
"""

# %%
print(f"{my_name} is {my_info} and this is {my_book}")
# Out:
# sepehr is
# 15 years old researcher
#  and this is sepehr's book

# %%
my_info
# Out:
# ' \n15 years old researcher\n'
