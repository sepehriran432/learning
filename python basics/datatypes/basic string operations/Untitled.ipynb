# %%
basic = "basic"
string = "string"
operations = "operations"
sentence = basic + " " + string + " " + operations
sentence
# Out:
# 'basic string operations'

# %%
"operation" in sentence
# Out:
# True

# %%
len(basic)
# Out:
# 5

# %%
sentence_length = len(sentence)

# %%
sentence_length
# Out:
# 23

# %%
len(basic) + len(string) + len(operations) + len("  ")
# Out:
# 23

# %%
the_first_and_end = sentence[0] + sentence[-1]

# %%
the_first_and_end
# Out:
# 'bs'

# %%
the_first_word = sentence[0:5]

# %%
the_first_word
# Out:
# 'basic'

# %%
double_jump = sentence[0:5:2]
double_jump
# Out:
# 'bsc'
