# %%
"I am \"steve\""
# Out:
# 'I am "steve"'

# %%
print("name: Sepehr\nage: 15\n")
# Out:
# name: Sepehr
# age: 15

# %%
print("You\t are\t Steve")
# Out:
# You	 are	 Steve

# %%
print(r"You\t are\t Steve")
# Out:
# You\t are\t Steve

# %%
print(r"the root directory is: '/root/' ")
# Out:
# the root directory is: '/root/'
