# %%
x = 1000

# %%
dir(x)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
x.__init__
# Out:
# <method-wrapper '__init__' of int object at 0x7f3900118af0>

# %%
id(x)
# Out:
# 139882791013104

# %%
TheNameIs = "MaMdAnI, M-A-M-D-A-N-I"

# %%
TheNameIs.upper()
# Out:
# 'MAMDANI, M-A-M-D-A-N-I'

# %%
TheNameIs.lower()
# Out:
# 'mamdani, m-a-m-d-a-n-i'

# %%
dir(TheNameIs.lower())
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
TheNameIs.title()
# Out:
# 'Mamdani, M-A-M-D-A-N-I'

# %%
text = "abcdefg"

# %%
text.title()
# Out:
# 'Abcdefg'

# %%
TheNameIs.isalpha()
# Out:
# False

# %%
text.isalpha()
# Out:
# True

# %%
numbers = "67"

# %%
numbers.isdigit()
# Out:
# True

# %%
text.isdigit()
# Out:
# False

# %%
TheNameIs
# Out:
# 'MaMdAnI, M-A-M-D-A-N-I'

# %%
TheNameIs.find("M-")
# Out:
# 9

# %%
TheNameIs.replace("-", "_")
# Out:
# 'MaMdAnI, M_A_M_D_A_N_I'

# %%
a = "       AAAAAAAAAAAAA          "

# %%
a
# Out:
# '       AAAAAAAAAAAAA          '

# %%
a.strip()
# Out:
# 'AAAAAAAAAAAAA'

# %%
TheNameIs.split()
# Out:
# ['MaMdAnI,', 'M-A-M-D-A-N-I']

# %%
TheNameIs.split(",")
# Out:
# ['MaMdAnI', ' M-A-M-D-A-N-I']

# %%
TheNameIs[0:10] = "aa"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 TheNameIs[0:10] = "aa"
#
# TypeError: 'str' object does not support item assignment

# %%
TheNameIs = "aa" + TheNameIs[11:]

# %%
TheNameIs
# Out:
# 'aaA-M-D-A-N-I'
