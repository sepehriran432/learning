# %%
type("hello")
# Out:
# str

# %%
12
# Out:
# 12

# %%
0x19
# Out:
# 25

# %%
0x8
# Out:
# 8

# %%
1.1 + 2.2
# Out:
# 3.3000000000000003

# %%
"ssasa ' sasa"
# Out:
# "ssasa ' sasa"

# %%
'ssasa \" sassa'
# Out:
# 'ssasa " sassa'

# %%
'hello,\
how are you?\
not bad.\
'
# Out:
# 'hello,how are you?not bad.'

# %%
print("wow \\ nooo")
# Out:
# wow \ nooo

# %%
print("death\t note")
# Out:
# death	 note

# %%
print(r"4 \ 2 = 2")
# Out:
# 4 \ 2 = 2

# %%
print("""
I am
Iron Man
:o
""")
# Out:
# I am
# Iron Man
# :o
